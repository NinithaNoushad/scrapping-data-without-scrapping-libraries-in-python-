# %%
import pandas as pd

# %%
scraper=pd.read_html("https://en.wikipedia.org/wiki/List_of_highest-grossing_Indian_films")
scraper
# Out:
# [    Rank  Peak                         Film  Year                 Director  \
#  0      1     1                       Dangal  2016            Nitesh Tiwari
#  1      2     1  Baahubali 2: The Conclusion  2017          S. S. Rajamouli
#  2      3     3           K.G.F: Chapter 2 *  2022           Prashanth Neel
#  3      4     4                        RRR *  2022          S. S. Rajamouli
#  4      5     3            Bajrangi Bhaijaan  2015               Kabir Khan
#  5      6     3             Secret Superstar  2017           Advait Chandan
#  6      7     1                           PK  2014          Rajkumar Hirani
#  7      8     5                          2.0  2018                S.Shankar
#  8      9     2     Baahubali: The Beginning  2015          S. S. Rajamouli
#  9     10     4                       Sultan  2016          Ali Abbas Zafar
#  10    11     8                        Sanju  2018          Rajkumar Hirani
# ...

# %%
for index, table in enumerate(scraper):
    print("-----------------------------------")
    print(index)
    print(table)
# Out:
# -----------------------------------
# 0
#     Rank  Peak                         Film  Year               Director  \
# 0      1     1                       Dangal  2016          Nitesh Tiwari
# 1      2     1  Baahubali 2: The Conclusion  2017        S. S. Rajamouli
# 2      3     3                        RRR *  2022        S. S. Rajamouli
# 3      4     4           K.G.F: Chapter 2 *  2022         Prashanth Neel
# 4      5     3            Bajrangi Bhaijaan  2015             Kabir Khan
# 5      6     3             Secret Superstar  2017         Advait Chandan
# 6      7     1                           PK  2014        Rajkumar Hirani
# 7      8     5                          2.0  2018              S.Shankar
# 8      9     2     Baahubali: The Beginning  2015        S. S. Rajamouli
# 9     10     4                       Sultan  2016        Ali Abbas Zafar
# 10    11     8                        Sanju  2018        Rajkumar Hirani
# ...

# %%
scraper[0].head()
# Out:
#    Rank  Peak                         Film  Year         Director  \
# 0     1     1                       Dangal  2016    Nitesh Tiwari
# 1     2     1  Baahubali 2: The Conclusion  2017  S. S. Rajamouli
# 2     3     3                        RRR *  2022  S. S. Rajamouli
# 3     4     4           K.G.F: Chapter 2 *  2022   Prashanth Neel
# 4     5     3            Bajrangi Bhaijaan  2015       Kabir Khan
#
#                                            Studio(s) Primary language  \
# 0  Aamir Khan Productions UTV Motion Pictures Wal...            Hindi
# 1                                   Arka Media Works      TeluguTamil
# 2                                 DVV Entertainments           Telugu
# 3                                      Hombale Films          Kannada
# 4  Salman Khan Films Kabir Khan Films Eros Intern...            Hindi
#
#                    Worldwide gross    Ref
# 0    ₹2,024 crore (US$311 million)    [9]
# 1    ₹1,810 crore (US$278 million)    [9]
# ...

# %%
scraper[7].head()
# Out:
#    Rank                 Film  Year              Director            Studio(s)  \
# 0     1              Lucifer  2019  Prithviraj Sukumaran    Aashirvad Cinemas
# 1     2          Pulimurugan  2016                Vysakh   Mulakuppadam Films
# 2     3                Kurup  2021     Srinath Rajendran       Wayfarer Films
# 3     4  Kayamkulam Kochunni  2018      Roshshan Andrews  Sree Gokulam Movies
# 4     5             Mamangam  2019         M. Padmakumar   Kavya Film Company
#
#               Worldwide gross Source
# 0  ₹175 crore (US$23 million)   [93]
# 1  ₹152 crore (US$20 million)   [94]
# 2  ₹118 crore (US$15 million)   [95]
# 3  ₹108 crore (US$14 million)   [96]
# 4  ₹135 crore (US$18 million)   [97]

# %%
scraper1=pd.read_html("https://en.wikipedia.org/wiki/List_of_schools_in_Ernakulam_district")

# %%
for index, table in enumerate(scraper1):
    print("-----------------------------------")
    print(index)
    print(table)
# Out:
# -----------------------------------
# 0
#     Sl No                             School          Location
# 0       1          Aluva Govt. HSS for Girls             Aluva
# 1       2             Ambalamugal Govt. VHSS       Ambalamugal
# 2       3               Binanipuram Govt. HS       Binanipuram
# 3       4           Chendamangalam Govt. HSS    Chendamangalam
# 4       5              Chengamanad Govt. HSS       Chengamanad
# 5       6                  Chowara Govt. HSS           Chowara
# 6       7                 Edathala Govt. HSS          Edathala
# 7       8                    Eloor Govt. HSS    Kutikkattukara
# 8       9                Ezhikkara Govt. HSS         Ezhikkara
# 9      10              Kadayirippu Govt. HSS       Kadayirippu
# 10     11               Kaitharam Govt. VHSS         Kaitharam
# 11     12       Kalamassery Govt. HSS & VHSS       Kalamassery
# 12     13  Keezhmad Model Residential School      Thottumugham
# ...

# %%
scraper1[15].head()
# Out:
#    Sl No                                    School      Location  \
# 0      1                 Dawn International School    Ambalamedu
# 1      2                      Global Public School  Thiruvaniyur
# 2      3  German Metropolitan International School      Kakkanad
# 3      4                  The Indian Public School      Kakkanad
#
#                    Qualification(s) offered:
# 0      Pearson IGCSE & Pearson GCE 'A' level
# 1  Cambridge IGCSE & Cambridge CGE 'A' level
# 2      Pearson IGCSE & Pearson GCE 'A' level
# 3                                 IB Diploma

# %%
scraper1[3].head()
# Out:
#    Sl No                            School         Location
# 0      1        Central Calvathy Govt. HSS       Fort Kochi
# 1      2    Chottanikkara Govt. HSS & VHSS    Chottanikkara
# 2      3                 Edacochi Govt. HS         Edacochi
# 3      4               Edappally Govt. HSS        Edappally
# 4      5  Edappally North Govt. HSS & VHSS  Edappally North
